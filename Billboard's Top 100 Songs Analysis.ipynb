# %%
import pandas as pd
raw_song_table = pd.read_csv('songs_dataset.csv')

# %% [markdown]
# 1. What is the name of the song that has the longest duration in the dataset?

# %%
sorted_by_duration = raw_song_table.sort_values(by = ['duration_ms'], ascending = False)
sorted_by_duration
# Out:
#       Unnamed: 0             artist  \
# 1381        1381  Justin Timberlake
# 140          140      Roger Sanchez
# 706          706  Justin Timberlake
# 760          760  Justin Timberlake
# 242          242        Dirty Vegas
# ...          ...                ...
# 1746        1746           Lil Pump
# 1853        1853       XXXTENTACION
# 1752        1752       XXXTENTACION
# 1939        1939          Lil Nas X
# 1931        1931          Lil Nas X
#
#                                                  song  duration_ms  explicit  \
# 1381                                          Mirrors       484146     False
# 140                                    Another Chance       452906     False
# 706   What Goes Around.../...Comes Around (Interlude)       448573     False
# 760        LoveStoned / I Think She Knows (Interlude)       444333      True
# 242                                        Days Go By       432146     False
# ...                                               ...          ...       ...
# 1746                                       Gucci Gang       124055      True
# 1853                                          changes       121886     False
# 1752                                   Jocelyn Flores       119133      True
# 1939                                           Panini       114893     False
# 1931                                    Old Town Road       113000     False
#
#       year  popularity  danceability  energy             genre
# 1381  2013          78         0.574   0.512               pop
# 140   2000          50         0.610   0.820  Dance/Electronic
# 706   2006          70         0.687   0.723               pop
# 760   2006          57         0.859   0.681               pop
# 242   2002          48         0.786   0.853  Dance/Electronic
# ...    ...         ...           ...     ...               ...
# 1746  2017          64         0.936   0.523           hip hop
# 1853  2018          79         0.669   0.308           hip hop
# 1752  2017          83         0.872   0.391           hip hop
# 1939  2019          71         0.703   0.594      hip hop, pop
# 1931  2019          76         0.907   0.530      hip hop, pop
#
# [2000 rows x 10 columns]

# %% [markdown]
# 2. What percentage of songs have a duration greater than 3 minutes? Note that the dataset gives duration in terms of milliseconds.

# %%
sorted_by_duration[sorted_by_duration.duration_ms > 180000]
# Out:
#       Unnamed: 0             artist  \
# 1381        1381  Justin Timberlake
# 140          140      Roger Sanchez
# 706          706  Justin Timberlake
# 760          760  Justin Timberlake
# 242          242        Dirty Vegas
# ...          ...                ...
# 1848        1848         Marshmello
# 1932        1932          Meek Mill
# 1866        1866       Charlie Puth
# 1063        1063              B.o.B
# 654          654       Fall Out Boy
#
#                                                  song  duration_ms  explicit  \
# 1381                                          Mirrors       484146     False
# 140                                    Another Chance       452906     False
# 706   What Goes Around.../...Comes Around (Interlude)       448573     False
# 760        LoveStoned / I Think She Knows (Interlude)       444333      True
# 242                                        Days Go By       432146     False
# ...                                               ...          ...       ...
# 1848                                          Silence       180822     False
# 1932                          Going Bad (feat. Drake)       180522      True
# 1866                      Done for Me (feat. Kehlani)       180493     False
# 1063    Airplanes (feat. Hayley Williams of Paramore)       180480      True
# 654                                      Dance, Dance       180266     False
#
#       year  popularity  danceability  energy                  genre
# 1381  2013          78         0.574   0.512                    pop
# 140   2000          50         0.610   0.820       Dance/Electronic
# 706   2006          70         0.687   0.723                    pop
# 760   2006          57         0.859   0.681                    pop
# 242   2002          48         0.786   0.853       Dance/Electronic
# ...    ...         ...           ...     ...                    ...
# 1848  2017          80         0.520   0.761  pop, Dance/Electronic
# 1932  2018          78         0.889   0.496           hip hop, pop
# 1866  2018          67         0.856   0.632                    pop
# 1063  2010          74         0.660   0.867           hip hop, pop
# 654   2005          74         0.622   0.961                   rock
#
# [1861 rows x 10 columns]

# %%
1861/2000
# Out:
# 0.9305

# %% [markdown]
# 3. What is the name of Katy Perry's least danceable song?

# %%
Katy = raw_song_table.where(raw_song_table.artist == "Katy Perry")
Katy = Katy.dropna()
sorted_Katy_dance = Katy.sort_values(by = ['danceability'])
sorted_Katy_dance
# Out:
#       Unnamed: 0      artist                          song  duration_ms  \
# 1290      1290.0  Katy Perry                    Wide Awake     220946.0
# 996        996.0  Katy Perry            Waking Up In Vegas     199186.0
# 1367      1367.0  Katy Perry                          Roar     223546.0
# 1360      1360.0  Katy Perry               Unconditionally     228878.0
# 1772      1772.0  Katy Perry         Chained To The Rhythm     237733.0
# 1121      1121.0  Katy Perry                          E.T.     229573.0
# 1103      1103.0  Katy Perry                      Firework     227893.0
# 1401      1401.0  Katy Perry                    Dark Horse     215672.0
# 1140      1140.0  Katy Perry  Last Friday Night (T.G.I.F.)     230746.0
# 1232      1232.0  Katy Perry                    Part Of Me     216160.0
# 1269      1269.0  Katy Perry         The One That Got Away     227333.0
# 1354      1354.0  Katy Perry             This Is How We Do     204285.0
# 801        801.0  Katy Perry               I Kissed A Girl     179640.0
# 818        818.0  Katy Perry                    Hot N Cold     220226.0
# 1087      1087.0  Katy Perry                 Teenage Dream     227741.0
# 1008      1008.0  Katy Perry              California Gurls     234653.0
#
#      explicit    year  popularity  danceability  energy genre
# 1290    False  2012.0        65.0         0.514   0.683   pop
# 996     False  2008.0        49.0         0.524   0.878   pop
# 1367    False  2013.0        73.0         0.554   0.772   pop
# 1360    False  2013.0         0.0         0.555   0.729   pop
# 1772    False  2017.0        69.0         0.562   0.800   pop
# 1121    False  2012.0        65.0         0.620   0.869   pop
# 1103    False  2010.0        72.0         0.638   0.832   pop
# 1401    False  2013.0        74.0         0.647   0.585   pop
# 1140    False  2012.0        74.0         0.649   0.815   pop
# 1232    False  2012.0        73.0         0.678   0.918   pop
# 1269    False  2012.0        72.0         0.687   0.792   pop
# 1354    False  2013.0        60.0         0.690   0.636   pop
# 801     False  2008.0        73.0         0.699   0.760   pop
# 818     False  2008.0        73.0         0.706   0.841   pop
# 1087    False  2010.0        69.0         0.719   0.798   pop
# 1008    False  2012.0        72.0         0.791   0.754   pop

# %% [markdown]
# 4. What artist has the highest number of explicit songs released in the years before and including 2008?

# %%
explicit_songs = raw_song_table.where(raw_song_table.explicit == True).dropna()
sorted_explicit = explicit_songs.sort_values(by = ['year'], ascending = False)
sorted_explicit[sorted_explicit.year < 2009]
sorted_explicit['artist'].value_counts()
# Out:
# Eminem             20
# Drake              18
# Kanye West         14
# JAY-Z              12
# 50 Cent             9
#                    ..
# Professor Green     1
# Mann                1
# Lupe Fiasco         1
# Mac Miller          1
# t.A.T.u.            1
# Name: artist, Length: 284, dtype: int64

# %% [markdown]
# Challenge Questions
# 1. You are a music producer hoping to create the next big hit. You have aligned all the artists, and you know the genre of the song you want to create. You just have one question: should your song be explicit? You know that your mom disapproves of profanity in songs, but it seems like kids these days don't mind. The only thing you have on your mind is business though. Will a song being explicit affect its popularity in the modern streaming ecosystem? What conclusions can you draw from this dataset, and what are the limitations of your thought process?

# %%
sorted_by_year = raw_song_table.sort_values(by = ['year'], ascending = False)
sorted_after_2015 = sorted_by_year[sorted_by_year.year > 2015]
sorted_after_2015
# Out:
#       Unnamed: 0         artist  \
# 1991        1991            NSG
# 568          568     Will Smith
# 308          308       t.A.T.u.
# 1999        1999    Post Malone
# 217          217        Aaliyah
# ...          ...            ...
# 1665        1665  Fifth Harmony
# 1677        1677     Tory Lanez
# 1678        1678           P!nk
# 1662        1662           Illy
# 1680        1680     Steve Aoki
#
#                                                    song  duration_ms  \
# 1991                                            Options       240081
# 568                                              Switch       197666
# 308                             All The Things She Said       214440
# 1999                                            Circles       215280
# 217                                       Rock The Boat       275026
# ...                                                 ...          ...
# 1665               Work from Home (feat. Ty Dolla $ign)       214480
# 1677                                                LUV       228640
# 1678  Just Like Fire (From the Original Motion Pictu...       215413
# 1662                        Papercuts (feat. Vera Blue)       255889
# 1680                                       Just Hold On       198774
#
#       explicit  year  popularity  danceability  energy  \
# 1991      True  2020          57         0.836   0.621
# 568      False  2020          34         0.873   0.900
# 308       True  2020          39         0.527   0.834
# 1999     False  2019          85         0.695   0.762
# 217      False  2019           0         0.641   0.720
# ...        ...   ...         ...           ...     ...
# 1665     False  2016          75         0.803   0.585
# 1677      True  2016           0         0.688   0.541
# 1678     False  2016          68         0.632   0.702
# 1662     False  2016          51         0.369   0.618
# 1680     False  2016          63         0.647   0.932
#
#                                genre
# 1991      World/Traditional, hip hop
# 568                     hip hop, pop
# 308                              pop
# 1999                         hip hop
# 217                hip hop, pop, R&B
# ...                              ...
# 1665                             pop
# 1677               hip hop, pop, R&B
# 1678                             pop
# 1662  hip hop, pop, Dance/Electronic
# 1680  hip hop, pop, Dance/Electronic
#
# [409 rows x 10 columns]

# %%
sorted_by_popular = sorted_after_2015.sort_values(by = ['popularity'], ascending = False) 
sorted_by_popular['explicit'].value_counts()
# Out:
# False    250
# True     159
# Name: explicit, dtype: int64

# %%
159/409
# Out:
# 0.38875305623471884

# %%
bottom_popular = sorted_by_popular[sorted_by_popular.popularity < 43]
bottom_popular['explicit'].value_counts()
# Out:
# False    48
# True     20
# Name: explicit, dtype: int64

# %%
20/68
# Out:
# 0.29411764705882354

# %%
top_half_popular = sorted_by_popular[sorted_by_popular.popularity > 43]
top_half_popular['explicit'].value_counts()
# Out:
# False    200
# True     139
# Name: explicit, dtype: int64

# %%
139/339
# Out:
# 0.41002949852507375

# %%
top_25_popular = sorted_by_popular[sorted_by_popular.popularity > 64]
top_25_popular['explicit'].value_counts()
# Out:
# False    153
# True     118
# Name: explicit, dtype: int64

# %%
118/271
# Out:
# 0.4354243542435424

# %%
top_10_popular = sorted_by_popular[sorted_by_popular.popularity > 75]
top_10_popular['explicit'].value_counts()
# Out:
# False    67
# True     57
# Name: explicit, dtype: int64

# %%
57/124
# Out:
# 0.4596774193548387

# %% [markdown]
# Yes, your song should be explicit. Since you are concerned with popularity in the modern streaming ecosystem, I first looked at the data from recent years(2015-2020). This data gives us a look at what is popular and unpopular among individuals in the modern age. I then sorted this table of songs by popularity and looked at the ratio of explicit songs to total songs. First, I looked at the total ratio of explicit songs to total songs, then looked at the same ratio in the bottom 50% of popular songs, top 50%, top 25% and top 10%. As the criteria of songs became more popular, the ratio of explicit songs within that population also became consistently higher which demonstrates that there is a positive correlation of a song being explicit and popular among the modern audience. Some limitations of my thought process are that while my analysis focuses on the fact that explicit songs become more prevalent as popularity of songs increase, it ignores the fact that nonexplicit songs maintain the majority in every category of popularity. This fact may be influenced by confounding variables not captured in the data set such as the ratio of songs produced that are explicit compared to nonexplicit.

# %% [markdown]
# 2. You are put in charge of organizing the 2024 Superbowl Half-Time Show, and you get to choose who gets to perform. You have to present your idea to the board, and if it's a flop, they're going to send the linebackers at you. What single artist would you pick, and why? Which metrics are most important in your decision, and what are potential drawbacks of your methodology? How can you create a good show and save your neck?

# %%
top_25_popular['artist'].value_counts()
# Out:
# Drake               9
# Post Malone         8
# Marshmello          6
# The Chainsmokers    6
# Migos               5
#                    ..
# ZAYN                1
# Garrett Nash        1
# Meek Mill           1
# Tones And I         1
# Bastille            1
# Name: artist, Length: 171, dtype: int64

# %%
top_energy = top_25_popular.sort_values(by = ['energy'], ascending = False)
top_energy = top_energy[top_energy.energy > .5]
top_dance = top_energy[top_energy.danceability > .65]
top_dance['artist'].value_counts()
# Out:
# Post Malone      6
# Drake            6
# Migos            5
# Calvin Harris    4
# Cardi B          4
#                 ..
# Becky G          1
# Eminem           1
# Lil Uzi Vert     1
# Halsey           1
# 2 Chainz         1
# Name: artist, Length: 114, dtype: int64

# %%
top_25_popular['artist'].value_counts()
# Out:
# Drake               9
# Post Malone         8
# Marshmello          6
# The Chainsmokers    6
# Migos               5
#                    ..
# ZAYN                1
# Garrett Nash        1
# Meek Mill           1
# Tones And I         1
# Bastille            1
# Name: artist, Length: 171, dtype: int64

# %% [markdown]
# The artist I chose was Drake. What makes Superbowl performances memorable are largely three metrics( Popularity, energy, and danceability). An artist must have multiple songs that are popular for audience to recognize the name and songs. They must have energy to get the crowd excited, pumped, and engaged. Lastly, danceability plays a huge part in making a Superbowl performance memorable as audiences often remember the choreography and theatrics over what actual songs played in the performance. Thus, I took the top 25% of songs by popularity. Then took the songs that had an energy greater than .5 and a danceability greater than a .65. I, then, counted the artists who had the most songs within this tailored group of songs and came with Post Malone and Drake. Because there was a tie, I went back to the top 25% of songs by popularity and counted to see who had the most songs within that population. Drake came out on top of Post Malone demonstrating that Drake would be a more recognizable artist to have on the big stage.
